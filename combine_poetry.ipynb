# %%
'''
combine poetry files
'''
import json
import os

data = []

all_poetry_file_path = [os.path.join("./poetry",file_path) for file_path in os.listdir('./poetry')]

len(all_poetry_file_path)

for file_path in all_poetry_file_path:
    with open(file_path,"r",encoding="utf-8") as f:
        json_file = json.load(f)
        print("current data size: ",len(json_file))
        data.extend(json_file)
        print("total data size: ",len(data))

with open("./data/all_poetry.json","w+")as f:
    json.dump(data,f)
# Out:
# current data size:  1000
# total data size:  1000
# current data size:  1000
# total data size:  2000
# current data size:  1000
# total data size:  3000
# current data size:  1000
# total data size:  4000
# current data size:  1000
# total data size:  5000
# current data size:  1000
# total data size:  6000
# current data size:  1000
# total data size:  7000
# current data size:  1000
# total data size:  8000
# current data size:  1000
# total data size:  9000
# current data size:  1000
# total data size:  10000
# current data size:  1000
# total data size:  11000
# current data size:  1000
# total data size:  12000
# current data size:  1000
# total data size:  13000
# current data size:  1000
# total data size:  14000
# current data size:  1000
# total data size:  15000
# current data size:  1000
# total data size:  16000
# current data size:  1000
# total data size:  17000
# current data size:  1000
# total data size:  18000
# current data size:  591
# total data size:  18591
# ...

# %%
'''
charset process
'''

with open("./data/all_poetry.json","r",encoding="utf-8") as f:
    poetrys = json.load(f)
# Out:
#   File "<ipython-input-2-65d6611bf670>", line 5
#     with open("./data/all_poetry.json".)
#                                        ^
# SyntaxError: invalid syntax
